# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham5787/EDA-Project-Prac/blob/main/self_project_practice_p.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
path = '/content/drive/MyDrive/Copy of International_T20_Data.csv'

# %%
df = pd.read_csv(path)

# %%
df.head(5)
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 3  [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 4  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
#
#   date created  meta.revision                          date gender match type  \
# 0   2017-02-18              2  [datetime.date(2017, 2, 17)]   male        T20
# 1   2017-02-19              2  [datetime.date(2017, 2, 19)]   male        T20
# 2   2017-02-23              1  [datetime.date(2017, 2, 22)]   male        T20
# 3   2016-09-12              1   [datetime.date(2016, 9, 5)]   male        T20
# 4   2016-06-19              1  [datetime.date(2016, 6, 18)]   male        T20
#
# ...

# %%
df.rename(columns = {'meta.created': 'date created' , 'info.dates' : 'date' , 'info.gender' : 'gender' ,
          'info.match_type' : 'match type' , 'info.outcome.by.wickets' : 'won by wickets' , 'info.outcome.winner' : 'winner' ,
          'info.overs' : 'overs' , '	info.outcome.by.runs' : 'won  by runs' , 
          'info.match_type_number ':' match type' , 'info.neutral_venue' : 'neutral venue' , 'info.outcome.method' : 'outcome method' , 
          '	info.outcome.result' : 'result' , 'info.outcome.eliminator':'eliminator' ,'info.umpires' : 'umpires' , 'info.venue' : 'venue' } , inplace = True)

# %%
df.columns
# Out:
# Index(['innings', 'meta.data_version', 'date created', 'meta.revision', 'date',
#        'gender', 'match type', 'won by wickets', 'winner', 'overs',
#        'info.player_of_match', 'info.teams', 'info.toss.decision',
#        'info.toss.winner', 'umpires', 'venue', 'info.city',
#        'info.outcome.by.runs', 'info.match_type_number', 'neutral venue',
#        'outcome method', 'info.outcome.result', 'eliminator',
#        'info.supersubs.New Zealand', 'info.supersubs.South Africa',
#        'info.bowl_out', 'info.outcome.bowl_out'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      1417 non-null   object
#  1   meta.data_version            1417 non-null   float64
#  2   date created                 1417 non-null   object
#  3   meta.revision                1417 non-null   int64
#  4   date                         1417 non-null   object
#  5   gender                       1417 non-null   object
#  6   match type                   1417 non-null   object
#  7   won by wickets               651 non-null    float64
#  8   winner                       1372 non-null   object
#  9   overs                        1417 non-null   int64
#  10  info.player_of_match         1255 non-null   object
#  11  info.teams                   1417 non-null   object
#  12  info.toss.decision           1417 non-null   object
# ...

# %%
top_stadiums = pd.DataFrame(df['venue'].value_counts())
top_stadiums[0:3]
# Out:
#                                      venue
# Dubai International Cricket Stadium     62
# Sheikh Zayed Stadium                    41
# Shere Bangla National Stadium           39

# %%
most_played  = df['info.teams'].value_counts()
[most_played[:3]]
# Out:
# [['England', 'Pakistan']      29
#  ['Australia', 'Pakistan']    26
#  ['England', 'Australia']     25
#  Name: info.teams, dtype: int64]

# %%
new_df.shape
# Out:
# (1417, 27)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1417 entries, 0 to 1416
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      1417 non-null   object
#  1   meta.data_version            1417 non-null   float64
#  2   date created                 1417 non-null   object
#  3   meta.revision                1417 non-null   int64
#  4   date                         1417 non-null   object
#  5   gender                       1417 non-null   object
#  6   match type                   1417 non-null   object
#  7   won by wickets               651 non-null    float64
#  8   winner                       1372 non-null   object
#  9   overs                        1417 non-null   int64
#  10  info.player_of_match         1255 non-null   object
#  11  info.teams                   1417 non-null   object
#  12  info.toss.decision           1417 non-null   object
# ...

# %%
# to remove te he rows which contain null values in winner column
new_df = df[df['winner'].notnull()]

# %%
new_df = new_df.reset_index()

# %%
import ast

# %%
df['teams'] = df['info.teams'].apply(lambda x : ast.literal_eval(x))

# %%
new1 = new_df.explode('teams')

# %%
new2 = new1[['teams' , "winner"]]

# %%
new2.groupby('teams')

# %%
match_played = new2['teams'].value_counts()

# %%
match_played = match_played.sort_values(by=['index']).reset_index()

# %%
match_played
# Out:
#     level_0                     index  teams
# 0        12               Afghanistan     74
# 1         1                 Australia    208
# 2        45                   Austria      4
# 3        64                   Bahrain      2
# 4         8                Bangladesh    135
# ..      ...                       ...    ...
# 66       14      United Arab Emirates     54
# 67       27  United States of America     13
# 68       29                   Vanuatu     12
# 69        5               West Indies    186
# 70       10                  Zimbabwe     75
#
# [71 rows x 3 columns]

# %%
match_won = new1['winner'].value_counts()/2

# %%
match_won = match_won.sort_values(by=['index']).reset_index()

# %%
match_won.shape
# Out:
# (56, 3)

# %%
new_df1 = pd.concat([match_played , match_won] , axis = 1 , ignore_index = True)

# %%
new_df1.rename(columns = {2:'matches played' , 5 : 'matches won'} , inplace= True)

# %%
new_df2 = new_df1.loc[new_df1['matches won']>=1]

# %%
new_df2['win percentage'] = (new_df2['matches won']/new_df2['matches played'])*100
# Out:
# <ipython-input-174-cf9b552d4456>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df2['win percentage'] = (new_df2['matches won']/new_df2['matches played'])*100

# %%
new_df2
# Out:
#      0                 1  matches played     3                         4  \
# 0   12       Afghanistan              74   8.0               Afghanistan
# 1    1         Australia             208   0.0                 Australia
# 2   45           Austria               4  54.0                   Bahrain
# 3   64           Bahrain               2   9.0                Bangladesh
# 4    8        Bangladesh             135  36.0                   Belgium
# 5   53           Belgium               3  32.0                   Bermuda
# 6   31           Bermuda              11  40.0                  Botswana
# 7   63            Bhutan               2  55.0                  Bulgaria
# 8   26          Botswana              16  25.0                    Canada
# 9   52          Bulgaria               3  30.0                     China
# 10  23            Canada              22  44.0                   Denmark
# 11  42    Cayman Islands               6   1.0                   England
# ...

# %%
new_df2.sort_values('win percentage' , ascending= False)
# Out:
#      0                 1  matches played     3                         4  \
# 34  65        Luxembourg               2   3.0                  Pakistan
# 54  62             Samoa               2   6.0               West Indies
# 16  59              Fiji               3   2.0                     India
# 45  46            Norway               4   4.0              South Africa
# 3   64           Bahrain               2   9.0                Bangladesh
# 55  66      Saudi Arabia               1  15.0                  Zimbabwe
# 11  42    Cayman Islands               6   1.0                   England
# 25  67              Iran               1  20.0                  Malaysia
# 18  48             Ghana               4  10.0                   Ireland
# 35  51            Malawi               3  17.0          Papua New Guinea
# 28  47             Italy               4  14.0                   Namibia
# 49  56       Philippines               3  19.0                  Thailand
# ...
